# %%
# Imports the libraries
import pandas as pd
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

# %%
# Imports the data from a .csv file to a dataframe
df = pd.DataFrame()

df_patient = pd.read_csv(f"1.csv").drop('0', axis=1)
df_patient = df_patient.rename(columns={df_patient.columns[0]: 'X',df_patient.columns[1]: 'Y', df_patient.columns[2]: 'Z', df_patient.columns[3]: 'Label'})
df = pd.concat([df, df_patient], ignore_index=True)

df
# Out:
#            X     Y     Z  Label
# 0       1667  2072  2047      1
# 1       1611  1957  1906      1
# 2       1601  1939  1831      1
# 3       1643  1965  1879      1
# 4       1604  1959  1921      1
# ...      ...   ...   ...    ...
# 162495  1927  2388  2074      7
# 162496  1930  2383  2074      7
# 162497  1929  2385  2076      7
# 162498  1926  2385  2078      7
# 162499  1922  2387  2078      0
#
# [162500 rows x 4 columns]

# %%
# Checks if there is any NaN
df.isna().sum()
# Out:
# X        0
# Y        0
# Z        0
# Label    0
# dtype: int64

# %%
# Splits the dataframe into X and Y
df_x = df[['X','Y','Z']]
df_y = df['Label']

# %%
# Scales the data
scaler = StandardScaler()
df_x = scaler.fit_transform(df_x)

# %%
# Splits the data into train and test
x_train, x_test, y_train, y_test = train_test_split(df_x, df_y, test_size=0.3,random_state=42)

x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((113750, 3), (48750, 3), (113750,), (48750,))

# %%
# Creates the SVC model
SVC_model = SVC()

# Trains the model
history = SVC_model.fit(x_train, y_train)

# Predicts the x_test data
y_pred = SVC_model.predict(x_test)

# Calculates the model accuracy
SVC_accuracy = accuracy_score(y_test, y_pred)
SVC_accuracy
# Out:
# 0.8407589743589744

# %%
# Creates the MLP model
MLP_model = Sequential([
    Dense(x_train.shape[1], kernel_initializer='random_uniform', activation='relu', input_dim=x_train.shape[1]),
    Dense(64, kernel_initializer='random_uniform', activation='relu'),
    Dropout(0.1),
    Dense(64, kernel_initializer='random_uniform', activation='relu'),
    Dense(8, kernel_initializer='random_uniform', activation='softmax')])

MLP_model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

# Trains the model
history = MLP_model.fit(x_train, y_train, validation_split=0.1, epochs=15)

# Calculate the model loss and accuracy
MLP_loss, MLP_accuracy = MLP_model.evaluate(x_test, y_test)
# Out:
# Epoch 1/15
# 3200/3200 [==============================] - 9s 3ms/step - loss: 0.7643 - accuracy: 0.7521 - val_loss: 0.6065 - val_accuracy: 0.8238
# Epoch 2/15
# 3200/3200 [==============================] - 8s 3ms/step - loss: 0.5912 - accuracy: 0.8291 - val_loss: 0.5720 - val_accuracy: 0.8323
# Epoch 3/15
# 3200/3200 [==============================] - 7s 2ms/step - loss: 0.5711 - accuracy: 0.8330 - val_loss: 0.5519 - val_accuracy: 0.8353
# Epoch 4/15
# 3200/3200 [==============================] - 8s 3ms/step - loss: 0.5531 - accuracy: 0.8347 - val_loss: 0.5330 - val_accuracy: 0.8345
# Epoch 5/15
# 3200/3200 [==============================] - 7s 2ms/step - loss: 0.5349 - accuracy: 0.8352 - val_loss: 0.5198 - val_accuracy: 0.8356
# Epoch 6/15
# 3200/3200 [==============================] - 11s 3ms/step - loss: 0.5246 - accuracy: 0.8370 - val_loss: 0.5145 - val_accuracy: 0.8382
# Epoch 7/15
# ...

# %%
# Displays and compares the models accuracy
df = pd.DataFrame({'Model':['MLP','SVC'],
                   'Accuracy':[round(MLP_accuracy,4),round(SVC_accuracy,4)]})

df
# Out:
#   Model  Accuracy
# 0   MLP    0.8479
# 1   SVC    0.8408
